# %%
import pandas as pd
from pathlib import Path

# ============================================================================
# 1. CHARGER LES CSV
# ============================================================================

# Chemin vers les fichiers CSV
CSV_PATH = Path('./csv')

print("\n" + "="*80)
print("📚 CHARGEMENT DES FICHIERS CSV")
print("="*80)

# Vérifier que le dossier existe
if not CSV_PATH.exists():
    print(f"\n❌ ERREUR: Le dossier '{CSV_PATH}' n'existe pas!")
    print(f"   Crée le dossier ou vérifie le chemin")
    exit(1)

print(f"\n✓ Dossier trouvé: {CSV_PATH.absolute()}")

# ============================================================================
# 2. LISTER LES FICHIERS CSV
# ============================================================================

csv_files = list(CSV_PATH.glob('*.csv'))
print(f"\n📄 Fichiers CSV trouvés: {len(csv_files)}")

for file in sorted(csv_files):
    size_kb = file.stat().st_size / 1024
    print(f"   • {file.name:20} ({size_kb:8.1f} KB)")

# ============================================================================
# 3. CHARGER TOUS LES CSV DANS UN DICTIONNAIRE
# ============================================================================

print("\n" + "="*80)
print("⏳ Chargement en cours...")
print("="*80)

dfs = {}  # Dictionnaire pour stocker les DataFrames

for filepath in sorted(CSV_PATH.glob('*.csv')):
    filename = filepath.name
    table_name = filename.replace('.csv', '')  # Enlever '.csv'

    try:
        df = pd.read_csv(filepath)
        dfs[table_name] = df

        # Afficher les info
        print(f"\n✓ {table_name.upper()}")
        print(f"  Lignes: {len(df):,}")
        print(f"  Colonnes: {len(df.columns)}")
        print(f"  Colonnes: {list(df.columns)}")

    except Exception as e:
        print(f"\n❌ Erreur lors du chargement de {filename}: {e}")

# ============================================================================
# 4. RÉSUMÉ
# ============================================================================

print("\n" + "="*80)
print("📊 RÉSUMÉ")
print("="*80)

print(f"\n✓ Nombre total de fichiers chargés: {len(dfs)}")
print(f"\nTableau récapitulatif:")
print("-" * 80)
print(f"{'Fichier':20} | {'Lignes':>12} | {'Colonnes':>9} | {'Mémoire':>10}")
print("-" * 80)

for name, df in sorted(dfs.items()):
    memory_mb = df.memory_usage(deep=True).sum() / 1024**2
    print(f"{name:20} | {len(df):>12,} | {len(df.columns):>9} | {memory_mb:>9.2f} MB")

print("-" * 80)
# Out:
# ================================================================================
# 📚 CHARGEMENT DES FICHIERS CSV
# ================================================================================
#
# ✓ Dossier trouvé: /home/omar/Bureau/4A/Bases_de_Données_Avancées/cineexplorer/data/csv
#
# 📄 Fichiers CSV trouvés: 12
#    • characters.csv       ( 45845.5 KB)
#    • directors.csv        (  8645.0 KB)
#    • episodes.csv         (  2896.5 KB)
#    • genres.csv           ( 11762.8 KB)
#    • knownformovies.csv   ( 27371.3 KB)
#    • movies.csv           ( 19232.2 KB)
#    • persons.csv          ( 18046.1 KB)
#    • principals.csv       ( 94617.9 KB)
#    • professions.csv      ( 25019.2 KB)
#    • ratings.csv          (  5514.5 KB)
#    • titles.csv           ( 94833.1 KB)
#    • writers.csv          ( 18558.6 KB)
#
# ================================================================================
# ⏳ Chargement en cours...
# ================================================================================
#
# ✓ CHARACTERS
#   Lignes: 1,405,274
#   Colonnes: 3
#   Colonnes: ["('mid',)", "('pid',)", "('name',)"]
#
# ✓ DIRECTORS
#   Lignes: 419,861
#   Colonnes: 2
#   Colonnes: ["('mid',)", "('pid',)"]
#
# ✓ EPISODES
#   Lignes: 115,576
#   Colonnes: 4
#   Colonnes: ["('mid',)", "('parentMid',)", "('seasonNumber',)", "('episodeNumber',)"]
#
# ✓ GENRES
#   Lignes: 649,379
#   Colonnes: 2
#   Colonnes: ["('mid',)", "('genre',)"]
#
# ✓ KNOWNFORMOVIES
#   Lignes: 1,328,773
#   Colonnes: 2
#   Colonnes: ["('pid',)", "('mid',)"]
#
# ✓ MOVIES
#   Lignes: 291,238
#   Colonnes: 8
#   Colonnes: ["('mid',)", "('titleType',)", "('primaryTitle',)", "('originalTitle',)", "('isAdult',)", "('startYear',)", "('endYear',)", "('runtimeMinutes',)"]
#
# ✓ PERSONS
#   Lignes: 632,324
#   Colonnes: 4
#   Colonnes: ["('pid',)", "('primaryName',)", "('birthYear',)", "('deathYear',)"]
#
# ✓ PRINCIPALS
#   Lignes: 2,745,688
#   Colonnes: 5
#   Colonnes: ["('mid',)", "('ordering',)", "('pid',)", "('category',)", "('job',)"]
#
# ✓ PROFESSIONS
#   Lignes: 1,231,760
#   Colonnes: 2
#   Colonnes: ["('pid',)", "('jobName',)"]
#
# ✓ RATINGS
#   Lignes: 291,238
#   Colonnes: 3
#   Colonnes: ["('mid',)", "('averageRating',)", "('numVotes',)"]
#
# ✓ TITLES
#   Lignes: 1,908,072
#   Colonnes: 8
#   Colonnes: ["('mid',)", "('ordering',)", "('title',)", "('region',)", "('language',)", "('types',)", "('attributes',)", "('isOriginalTitle',)"]
#
# ✓ WRITERS
#   Lignes: 900,485
#   Colonnes: 2
#   Colonnes: ["('mid',)", "('pid',)"]
#
# ================================================================================
# 📊 RÉSUMÉ
# ================================================================================
#
# ✓ Nombre total de fichiers chargés: 12
#
# Tableau récapitulatif:
# --------------------------------------------------------------------------------
# Fichier              |       Lignes |  Colonnes |    Mémoire
# --------------------------------------------------------------------------------
# characters           |    1,405,274 |         3 |    236.85 MB
# directors            |      419,861 |         2 |     46.48 MB
# episodes             |      115,576 |         4 |     14.57 MB
# genres               |      649,379 |         2 |     70.32 MB
# knownformovies       |    1,328,773 |         2 |    147.12 MB
# movies               |      291,238 |         8 |     77.90 MB
# persons              |      632,324 |         4 |     82.97 MB
# principals           |    2,745,688 |         5 |    576.08 MB
# professions          |    1,231,760 |         2 |    135.43 MB
# ratings              |      291,238 |         3 |     20.58 MB
# titles               |    1,908,072 |         8 |    580.87 MB
# writers              |      900,485 |         2 |     99.71 MB
# --------------------------------------------------------------------------------

# %%
import pandas as pd
from pathlib import Path
import numpy as np

# ============================================================================
# 1. CHARGER LES CSV
# ============================================================================

# Chemin vers les fichiers CSV
CSV_PATH = Path('./csv')

print("\n" + "="*80)
print("📚 CHARGEMENT DES FICHIERS CSV")
print("="*80)

# Vérifier que le dossier existe
if not CSV_PATH.exists():
    print(f"\n❌ ERREUR: Le dossier '{CSV_PATH}' n'existe pas!")
    print(f"   Crée le dossier ou vérifie le chemin")
    exit(1)

print(f"\n✓ Dossier trouvé: {CSV_PATH.absolute()}")

# ============================================================================
# 2. LISTER LES FICHIERS CSV
# ============================================================================

csv_files = list(CSV_PATH.glob('*.csv'))
print(f"\n📄 Fichiers CSV trouvés: {len(csv_files)}")

for file in sorted(csv_files):
    size_kb = file.stat().st_size / 1024
    print(f"   • {file.name:20} ({size_kb:8.1f} KB)")

# ============================================================================
# 3. CHARGER TOUS LES CSV DANS UN DICTIONNAIRE
# ============================================================================

print("\n" + "="*80)
print("⏳ Chargement en cours...")
print("="*80)

dfs = {}  # Dictionnaire pour stocker les DataFrames

for filepath in sorted(CSV_PATH.glob('*.csv')):
    filename = filepath.name
    table_name = filename.replace('.csv', '')  # Enlever '.csv'

    try:
        df = pd.read_csv(filepath)
        dfs[table_name] = df

        # Afficher les info
        print(f"\n✓ {table_name.upper()}")
        print(f"  Lignes: {len(df):,}")
        print(f"  Colonnes: {len(df.columns)}")
        print(f"  Colonnes: {list(df.columns)}")

    except Exception as e:
        print(f"\n❌ Erreur lors du chargement de {filename}: {e}")

# ============================================================================
# 4. RÉSUMÉ DU CHARGEMENT
# ============================================================================

print("\n" + "="*80)
print("📊 RÉSUMÉ DU CHARGEMENT")
print("="*80)

print(f"\n✓ Nombre total de fichiers chargés: {len(dfs)}")
print(f"\nTableau récapitulatif:")
print("-" * 80)
print(f"{'Fichier':20} | {'Lignes':>12} | {'Colonnes':>9} | {'Mémoire':>10}")
print("-" * 80)

for name, df in sorted(dfs.items()):
    memory_mb = df.memory_usage(deep=True).sum() / 1024**2
    print(f"{name:20} | {len(df):>12,} | {len(df.columns):>9} | {memory_mb:>9.2f} MB")

print("-" * 80)

# ============================================================================
# 5. STATISTIQUES DESCRIPTIVES POUR CHAQUE FICHIER
# ============================================================================

print("\n" + "="*80)
print("📊 STATISTIQUES DESCRIPTIVES DÉTAILLÉES")
print("="*80)

for table_name, df in sorted(dfs.items()):
    print(f"\n\n{'='*80}")
    print(f"📋 TABLE: {table_name.upper()}")
    print(f"{'='*80}")

    # ========================
    # 1. DIMENSIONS
    # ========================
    print(f"\n1️⃣  DIMENSIONS:")
    print(f"   • Nombre de lignes: {len(df):,}")
    print(f"   • Nombre de colonnes: {len(df.columns)}")
    print(f"   • Mémoire utilisée: {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")

    # ========================
    # 2. TYPES DE DONNÉES
    # ========================
    print(f"\n2️⃣  TYPES DE DONNÉES:")
    for col in df.columns:
        dtype = df[col].dtype
        print(f"   • {col:25} : {dtype}")

    # ========================
    # 3. VALEURS MANQUANTES (NaN)
    # ========================
    print(f"\n3️⃣  VALEURS MANQUANTES (NaN):")
    missing = df.isnull().sum()
    has_missing = missing.sum() > 0

    if not has_missing:
        print(f"   ✓ Aucune valeur manquante détectée")
    else:
        for col in df.columns:
            if missing[col] > 0:
                pct = (missing[col] / len(df) * 100)
                print(f"   • {col:25} : {missing[col]:>8,} valeurs manquantes ({pct:>6.2f}%)")

    # ========================
    # 4. CHAÎNES VIDES
    # ========================
    print(f"\n4️⃣  CHAÎNES VIDES (pour colonnes texte):")
    has_empty = False
    for col in df.columns:
        if df[col].dtype == 'object':  # Colonne texte
            empty_count = (df[col] == '').sum()
            if empty_count > 0:
                pct = (empty_count / len(df) * 100)
                print(f"   • {col:25} : {empty_count:>8,} chaînes vides ({pct:>6.2f}%)")
                has_empty = True

    if not has_empty:
        print(f"   ✓ Aucune chaîne vide détectée")

    # ========================
    # 5. VALEURS UNIQUES (CARDINALITÉ)
    # ========================
    print(f"\n5️⃣  VALEURS UNIQUES (CARDINALITÉ):")
    for col in df.columns:
        unique_count = df[col].nunique()
        pct = (unique_count / len(df) * 100)
        print(f"   • {col:25} : {unique_count:>8,} uniques ({pct:>6.2f}%)")

    # ========================
    # 6. APERÇU DES DONNÉES
    # ========================
    print(f"\n6️⃣  PREMIÈRES LIGNES:")
    print(df.head(3).to_string())

    # ========================
    # 7. STATISTIQUES POUR COLONNES NUMÉRIQUES
    # ========================
    numeric_cols = df.select_dtypes(include=[np.number]).columns
    if len(numeric_cols) > 0:
        print(f"\n7️⃣  STATISTIQUES NUMÉRIQUES:")
        print(df[numeric_cols].describe().to_string())
    else:
        print(f"\n7️⃣  STATISTIQUES NUMÉRIQUES:")
        print(f"   (Aucune colonne numérique)")

# ============================================================================
# 6. RÉSUMÉ GLOBAL
# ============================================================================

print(f"\n\n{'='*80}")
print(f"📊 RÉSUMÉ GLOBAL DE L'EXPLORATION")
print(f"{'='*80}")

total_rows = sum(len(df) for df in dfs.values())
total_cols = sum(len(df.columns) for df in dfs.values())
total_memory = sum(df.memory_usage(deep=True).sum() / 1024**2 for df in dfs.values())

print(f"\n✓ Total des lignes: {total_rows:,}")
print(f"✓ Total des colonnes: {total_cols}")
print(f"✓ Mémoire totale: {total_memory:.2f} MB")

print(f"\n✅ Exploration des données terminée!")
# Out:
# ================================================================================
# 📚 CHARGEMENT DES FICHIERS CSV
# ================================================================================
#
# ✓ Dossier trouvé: /home/omar/Bureau/4A/Bases_de_Données_Avancées/cineexplorer/data/csv
#
# 📄 Fichiers CSV trouvés: 12
#    • characters.csv       ( 45845.5 KB)
#    • directors.csv        (  8645.0 KB)
#    • episodes.csv         (  2896.5 KB)
#    • genres.csv           ( 11762.8 KB)
#    • knownformovies.csv   ( 27371.3 KB)
#    • movies.csv           ( 19232.2 KB)
#    • persons.csv          ( 18046.1 KB)
#    • principals.csv       ( 94617.9 KB)
#    • professions.csv      ( 25019.2 KB)
#    • ratings.csv          (  5514.5 KB)
#    • titles.csv           ( 94833.1 KB)
#    • writers.csv          ( 18558.6 KB)
#
# ================================================================================
# ⏳ Chargement en cours...
# ================================================================================
#
# ✓ CHARACTERS
#   Lignes: 1,405,274
#   Colonnes: 3
#   Colonnes: ["('mid',)", "('pid',)", "('name',)"]
#
# ✓ DIRECTORS
#   Lignes: 419,861
#   Colonnes: 2
#   Colonnes: ["('mid',)", "('pid',)"]
#
# ✓ EPISODES
#   Lignes: 115,576
#   Colonnes: 4
#   Colonnes: ["('mid',)", "('parentMid',)", "('seasonNumber',)", "('episodeNumber',)"]
#
# ✓ GENRES
#   Lignes: 649,379
#   Colonnes: 2
#   Colonnes: ["('mid',)", "('genre',)"]
#
# ✓ KNOWNFORMOVIES
#   Lignes: 1,328,773
#   Colonnes: 2
#   Colonnes: ["('pid',)", "('mid',)"]
#
# ✓ MOVIES
#   Lignes: 291,238
#   Colonnes: 8
#   Colonnes: ["('mid',)", "('titleType',)", "('primaryTitle',)", "('originalTitle',)", "('isAdult',)", "('startYear',)", "('endYear',)", "('runtimeMinutes',)"]
#
# ✓ PERSONS
#   Lignes: 632,324
#   Colonnes: 4
#   Colonnes: ["('pid',)", "('primaryName',)", "('birthYear',)", "('deathYear',)"]
#
# ✓ PRINCIPALS
#   Lignes: 2,745,688
#   Colonnes: 5
#   Colonnes: ["('mid',)", "('ordering',)", "('pid',)", "('category',)", "('job',)"]
#
# ✓ PROFESSIONS
#   Lignes: 1,231,760
#   Colonnes: 2
#   Colonnes: ["('pid',)", "('jobName',)"]
#
# ✓ RATINGS
#   Lignes: 291,238
#   Colonnes: 3
#   Colonnes: ["('mid',)", "('averageRating',)", "('numVotes',)"]
#
# ✓ TITLES
#   Lignes: 1,908,072
#   Colonnes: 8
#   Colonnes: ["('mid',)", "('ordering',)", "('title',)", "('region',)", "('language',)", "('types',)", "('attributes',)", "('isOriginalTitle',)"]
#
# ✓ WRITERS
#   Lignes: 900,485
#   Colonnes: 2
#   Colonnes: ["('mid',)", "('pid',)"]
#
# ================================================================================
# 📊 RÉSUMÉ DU CHARGEMENT
# ================================================================================
#
# ✓ Nombre total de fichiers chargés: 12
#
# Tableau récapitulatif:
# --------------------------------------------------------------------------------
# Fichier              |       Lignes |  Colonnes |    Mémoire
# --------------------------------------------------------------------------------
# characters           |    1,405,274 |         3 |    236.85 MB
# directors            |      419,861 |         2 |     46.48 MB
# episodes             |      115,576 |         4 |     14.57 MB
# genres               |      649,379 |         2 |     70.32 MB
# knownformovies       |    1,328,773 |         2 |    147.12 MB
# movies               |      291,238 |         8 |     77.90 MB
# persons              |      632,324 |         4 |     82.97 MB
# principals           |    2,745,688 |         5 |    576.08 MB
# professions          |    1,231,760 |         2 |    135.43 MB
# ratings              |      291,238 |         3 |     20.58 MB
# titles               |    1,908,072 |         8 |    580.87 MB
# writers              |      900,485 |         2 |     99.71 MB
# --------------------------------------------------------------------------------
#
# ================================================================================
# 📊 STATISTIQUES DESCRIPTIVES DÉTAILLÉES
# ================================================================================
#
#
# ================================================================================
# 📋 TABLE: CHARACTERS
# ================================================================================
#
# 1️⃣  DIMENSIONS:
#    • Nombre de lignes: 1,405,274
#    • Nombre de colonnes: 3
#    • Mémoire utilisée: 236.85 MB
#
# 2️⃣  TYPES DE DONNÉES:
#    • ('mid',)                  : object
#    • ('pid',)                  : object
#    • ('name',)                 : object
#
# 3️⃣  VALEURS MANQUANTES (NaN):
#    • ('name',)                 :        1 valeurs manquantes (  0.00%)
#
# 4️⃣  CHAÎNES VIDES (pour colonnes texte):
#    ✓ Aucune chaîne vide détectée
#
# 5️⃣  VALEURS UNIQUES (CARDINALITÉ):
#    • ('mid',)                  :  282,474 uniques ( 20.10%)
#    • ('pid',)                  :  296,694 uniques ( 21.11%)
#    • ('name',)                 :  496,806 uniques ( 35.35%)
#
# 6️⃣  PREMIÈRES LIGNES:
#     ('mid',)   ('pid',)   ('name',)
# 0  tt0000001  nm1588970        Self
# 1  tt0000005  nm0443482  Blacksmith
# 2  tt0000005  nm0653042   Assistant
#
# 7️⃣  STATISTIQUES NUMÉRIQUES:
#    (Aucune colonne numérique)
#
#
# ================================================================================
# 📋 TABLE: DIRECTORS
# ================================================================================
#
# 1️⃣  DIMENSIONS:
#    • Nombre de lignes: 419,861
#    • Nombre de colonnes: 2
#    • Mémoire utilisée: 46.48 MB
#
# 2️⃣  TYPES DE DONNÉES:
#    • ('mid',)                  : object
#    • ('pid',)                  : object
#
# 3️⃣  VALEURS MANQUANTES (NaN):
#    ✓ Aucune valeur manquante détectée
#
# 4️⃣  CHAÎNES VIDES (pour colonnes texte):
#    ✓ Aucune chaîne vide détectée
#
# 5️⃣  VALEURS UNIQUES (CARDINALITÉ):
#    • ('mid',)                  :  279,440 uniques ( 66.56%)
#    • ('pid',)                  :   89,307 uniques ( 21.27%)
#
# 6️⃣  PREMIÈRES LIGNES:
#     ('mid',)   ('pid',)
# 0  tt0000001  nm0005690
# 1  tt0000002  nm0721526
# 2  tt0000003  nm0721526
#
# 7️⃣  STATISTIQUES NUMÉRIQUES:
#    (Aucune colonne numérique)
#
#
# ================================================================================
# 📋 TABLE: EPISODES
# ================================================================================
#
# 1️⃣  DIMENSIONS:
#    • Nombre de lignes: 115,576
#    • Nombre de colonnes: 4
#    • Mémoire utilisée: 14.57 MB
#
# 2️⃣  TYPES DE DONNÉES:
#    • ('mid',)                  : object
#    • ('parentMid',)            : object
#    • ('seasonNumber',)         : float64
#    • ('episodeNumber',)        : float64
#
# 3️⃣  VALEURS MANQUANTES (NaN):
#    • ('seasonNumber',)         :      628 valeurs manquantes (  0.54%)
#    • ('episodeNumber',)        :      628 valeurs manquantes (  0.54%)
#
# 4️⃣  CHAÎNES VIDES (pour colonnes texte):
#    ✓ Aucune chaîne vide détectée
#
# 5️⃣  VALEURS UNIQUES (CARDINALITÉ):
#    • ('mid',)                  :  115,576 uniques (100.00%)
#    • ('parentMid',)            :    5,231 uniques (  4.53%)
#    • ('seasonNumber',)         :       63 uniques (  0.05%)
#    • ('episodeNumber',)        :    1,193 uniques (  1.03%)
#
# 6️⃣  PREMIÈRES LIGNES:
#     ('mid',) ('parentMid',)  ('seasonNumber',)  ('episodeNumber',)
# 0  tt0020666     tt15180956                1.0                 2.0
# 1  tt0020829     tt15180956                1.0                 1.0
# 2  tt0021166     tt15180956                1.0                 3.0
#
# 7️⃣  STATISTIQUES NUMÉRIQUES:
#        ('seasonNumber',)  ('episodeNumber',)
# count      114948.000000       114948.000000
# mean            3.675157           20.706293
# std            12.607253           93.682163
# min             1.000000            0.000000
# 25%             1.000000            4.000000
# 50%             2.000000            8.000000
# 75%             4.000000           14.000000
# max          2003.000000         9635.000000
#
#
# ================================================================================
# 📋 TABLE: GENRES
# ================================================================================
#
# 1️⃣  DIMENSIONS:
#    • Nombre de lignes: 649,379
#    • Nombre de colonnes: 2
#    • Mémoire utilisée: 70.32 MB
#
# 2️⃣  TYPES DE DONNÉES:
#    • ('mid',)                  : object
#    • ('genre',)                : object
#
# 3️⃣  VALEURS MANQUANTES (NaN):
#    ✓ Aucune valeur manquante détectée
#
# 4️⃣  CHAÎNES VIDES (pour colonnes texte):
#    ✓ Aucune chaîne vide détectée
#
# 5️⃣  VALEURS UNIQUES (CARDINALITÉ):
#    • ('mid',)                  :  290,841 uniques ( 44.79%)
#    • ('genre',)                :       28 uniques (  0.00%)
#
# 6️⃣  PREMIÈRES LIGNES:
#     ('mid',)   ('genre',)
# 0  tt0000001  Documentary
# 1  tt0000001        Short
# 2  tt0000002    Animation
#
# 7️⃣  STATISTIQUES NUMÉRIQUES:
#    (Aucune colonne numérique)
#
#
# ================================================================================
# 📋 TABLE: KNOWNFORMOVIES
# ================================================================================
#
# 1️⃣  DIMENSIONS:
#    • Nombre de lignes: 1,328,773
#    • Nombre de colonnes: 2
#    • Mémoire utilisée: 147.12 MB
#
# 2️⃣  TYPES DE DONNÉES:
#    • ('pid',)                  : object
#    • ('mid',)                  : object
#
# 3️⃣  VALEURS MANQUANTES (NaN):
#    ✓ Aucune valeur manquante détectée
#
# 4️⃣  CHAÎNES VIDES (pour colonnes texte):
#    ✓ Aucune chaîne vide détectée
#
# 5️⃣  VALEURS UNIQUES (CARDINALITÉ):
#    • ('pid',)                  :  590,094 uniques ( 44.41%)
#    • ('mid',)                  :  156,969 uniques ( 11.81%)
#
# 6️⃣  PREMIÈRES LIGNES:
#     ('pid',)   ('mid',)
# 0  nm0000001  tt0031983
# 1  nm0000001  tt0053137
# 2  nm0000001  tt0050419
#
# 7️⃣  STATISTIQUES NUMÉRIQUES:
#    (Aucune colonne numérique)
#
#
# ================================================================================
# 📋 TABLE: MOVIES
# ================================================================================
#
# 1️⃣  DIMENSIONS:
#    • Nombre de lignes: 291,238
#    • Nombre de colonnes: 8
#    • Mémoire utilisée: 77.90 MB
#
# 2️⃣  TYPES DE DONNÉES:
#    • ('mid',)                  : object
#    • ('titleType',)            : object
#    • ('primaryTitle',)         : object
#    • ('originalTitle',)        : object
#    • ('isAdult',)              : int64
#    • ('startYear',)            : int64
#    • ('endYear',)              : float64
#    • ('runtimeMinutes',)       : float64
#
# 3️⃣  VALEURS MANQUANTES (NaN):
#    • ('endYear',)              :  275,981 valeurs manquantes ( 94.76%)
#    • ('runtimeMinutes',)       :   24,555 valeurs manquantes (  8.43%)
#
# 4️⃣  CHAÎNES VIDES (pour colonnes texte):
#    ✓ Aucune chaîne vide détectée
#
# 5️⃣  VALEURS UNIQUES (CARDINALITÉ):
#    • ('mid',)                  :  291,238 uniques (100.00%)
#    • ('titleType',)            :       10 uniques (  0.00%)
#    • ('primaryTitle',)         :  236,664 uniques ( 81.26%)
#    • ('originalTitle',)        :  242,433 uniques ( 83.24%)
#    • ('isAdult',)              :        1 uniques (  0.00%)
#    • ('startYear',)            :      141 uniques (  0.05%)
#    • ('endYear',)              :       75 uniques (  0.03%)
#    • ('runtimeMinutes',)       :      582 uniques (  0.20%)
#
# 6️⃣  PREMIÈRES LIGNES:
#     ('mid',) ('titleType',)       ('primaryTitle',)      ('originalTitle',)  ('isAdult',)  ('startYear',)  ('endYear',)  ('runtimeMinutes',)
# 0  tt0000001          short              Carmencita              Carmencita             0            1894           NaN                  1.0
# 1  tt0000002          short  Le clown et ses chiens  Le clown et ses chiens             0            1892           NaN                  5.0
# 2  tt0000003          short          Pauvre Pierrot          Pauvre Pierrot             0            1892           NaN                  4.0
#
# 7️⃣  STATISTIQUES NUMÉRIQUES:
#        ('isAdult',)  ('startYear',)  ('endYear',)  ('runtimeMinutes',)
# count      291238.0   291238.000000  15257.000000        266683.000000
# mean            0.0     2000.666331   2005.703480            68.114525
# std             0.0       21.751575     14.598948           111.103795
# min             0.0     1874.000000   1934.000000             0.000000
# 25%             0.0     1994.000000   1999.000000            30.000000
# 50%             0.0     2008.000000   2010.000000            60.000000
# 75%             0.0     2016.000000   2017.000000            94.000000
# max             0.0     2022.000000   2023.000000         51420.000000
#
#
# ================================================================================
# 📋 TABLE: PERSONS
# ================================================================================
#
# 1️⃣  DIMENSIONS:
#    • Nombre de lignes: 632,324
#    • Nombre de colonnes: 4
#    • Mémoire utilisée: 82.97 MB
#
# 2️⃣  TYPES DE DONNÉES:
#    • ('pid',)                  : object
#    • ('primaryName',)          : object
#    • ('birthYear',)            : float64
#    • ('deathYear',)            : float64
#
# 3️⃣  VALEURS MANQUANTES (NaN):
#    • ('birthYear',)            :  447,348 valeurs manquantes ( 70.75%)
#    • ('deathYear',)            :  569,197 valeurs manquantes ( 90.02%)
#
# 4️⃣  CHAÎNES VIDES (pour colonnes texte):
#    ✓ Aucune chaîne vide détectée
#
# 5️⃣  VALEURS UNIQUES (CARDINALITÉ):
#    • ('pid',)                  :  632,324 uniques (100.00%)
#    • ('primaryName',)          :  602,187 uniques ( 95.23%)
#    • ('birthYear',)            :      357 uniques (  0.06%)
#    • ('deathYear',)            :      306 uniques (  0.05%)
#
# 6️⃣  PREMIÈRES LIGNES:
#     ('pid',) ('primaryName',)  ('birthYear',)  ('deathYear',)
# 0  nm0000001     Fred Astaire          1899.0          1987.0
# 1  nm0000002    Lauren Bacall          1924.0          2014.0
# 2  nm0000003  Brigitte Bardot          1934.0             NaN
#
# 7️⃣  STATISTIQUES NUMÉRIQUES:
#        ('birthYear',)  ('deathYear',)
# count   184976.000000    63127.000000
# mean      1951.257028     1991.365153
# std         33.937956       37.980116
# min          4.000000       17.000000
# 25%       1932.000000     1979.000000
# 50%       1957.000000     1999.000000
# 75%       1975.000000     2012.000000
# max       2018.000000     2022.000000
#
#
# ================================================================================
# 📋 TABLE: PRINCIPALS
# ================================================================================
#
# 1️⃣  DIMENSIONS:
#    • Nombre de lignes: 2,745,688
#    • Nombre de colonnes: 5
#    • Mémoire utilisée: 576.08 MB
#
# 2️⃣  TYPES DE DONNÉES:
#    • ('mid',)                  : object
#    • ('ordering',)             : int64
#    • ('pid',)                  : object
#    • ('category',)             : object
#    • ('job',)                  : object
#
# 3️⃣  VALEURS MANQUANTES (NaN):
#    • ('job',)                  : 1,966,495 valeurs manquantes ( 71.62%)
#
# 4️⃣  CHAÎNES VIDES (pour colonnes texte):
#    ✓ Aucune chaîne vide détectée
#
# 5️⃣  VALEURS UNIQUES (CARDINALITÉ):
#    • ('mid',)                  :  290,668 uniques ( 10.59%)
#    • ('ordering',)             :       10 uniques (  0.00%)
#    • ('pid',)                  :  577,549 uniques ( 21.03%)
#    • ('category',)             :       12 uniques (  0.00%)
#    • ('job',)                  :   14,023 uniques (  0.51%)
#
# 6️⃣  PREMIÈRES LIGNES:
#     ('mid',)  ('ordering',)   ('pid',)    ('category',)                 ('job',)
# 0  tt0000001              1  nm1588970             self                      NaN
# 1  tt0000001              2  nm0005690         director                      NaN
# 2  tt0000001              3  nm0374658  cinematographer  director of photography
#
# 7️⃣  STATISTIQUES NUMÉRIQUES:
#        ('ordering',)
# count   2.745688e+06
# mean    5.358562e+00
# std     2.848025e+00
# min     1.000000e+00
# 25%     3.000000e+00
# 50%     5.000000e+00
# 75%     8.000000e+00
# max     1.000000e+01
#
#
# ================================================================================
# 📋 TABLE: PROFESSIONS
# ================================================================================
#
# 1️⃣  DIMENSIONS:
#    • Nombre de lignes: 1,231,760
#    • Nombre de colonnes: 2
#    • Mémoire utilisée: 135.43 MB
#
# 2️⃣  TYPES DE DONNÉES:
#    • ('pid',)                  : object
#    • ('jobName',)              : object
#
# 3️⃣  VALEURS MANQUANTES (NaN):
#    • ('jobName',)              :   36,899 valeurs manquantes (  3.00%)
#
# 4️⃣  CHAÎNES VIDES (pour colonnes texte):
#    ✓ Aucune chaîne vide détectée
#
# 5️⃣  VALEURS UNIQUES (CARDINALITÉ):
#    • ('pid',)                  :  632,324 uniques ( 51.34%)
#    • ('jobName',)              :       38 uniques (  0.00%)
#
# 6️⃣  PREMIÈRES LIGNES:
#     ('pid',)   ('jobName',)
# 0  nm0000001     soundtrack
# 1  nm0000001          actor
# 2  nm0000001  miscellaneous
#
# 7️⃣  STATISTIQUES NUMÉRIQUES:
#    (Aucune colonne numérique)
#
#
# ================================================================================
# 📋 TABLE: RATINGS
# ================================================================================
#
# 1️⃣  DIMENSIONS:
#    • Nombre de lignes: 291,238
#    • Nombre de colonnes: 3
#    • Mémoire utilisée: 20.58 MB
#
# 2️⃣  TYPES DE DONNÉES:
#    • ('mid',)                  : object
#    • ('averageRating',)        : float64
#    • ('numVotes',)             : int64
#
# 3️⃣  VALEURS MANQUANTES (NaN):
#    ✓ Aucune valeur manquante détectée
#
# 4️⃣  CHAÎNES VIDES (pour colonnes texte):
#    ✓ Aucune chaîne vide détectée
#
# 5️⃣  VALEURS UNIQUES (CARDINALITÉ):
#    • ('mid',)                  :  291,238 uniques (100.00%)
#    • ('averageRating',)        :       91 uniques (  0.03%)
#    • ('numVotes',)             :   19,957 uniques (  6.85%)
#
# 6️⃣  PREMIÈRES LIGNES:
#     ('mid',)  ('averageRating',)  ('numVotes',)
# 0  tt0000001                 5.7           1864
# 1  tt0000002                 6.0            244
# 2  tt0000003                 6.5           1633
#
# 7️⃣  STATISTIQUES NUMÉRIQUES:
#        ('averageRating',)  ('numVotes',)
# count       291238.000000   2.912380e+05
# mean             6.832635   4.110613e+03
# std              1.400024   3.399732e+04
# min              1.000000   1.010000e+02
# 25%              6.100000   1.700000e+02
# 50%              7.100000   3.330000e+02
# 75%              7.800000   9.850000e+02
# max             10.000000   2.554860e+06
#
#
# ================================================================================
# 📋 TABLE: TITLES
# ================================================================================
#
# 1️⃣  DIMENSIONS:
#    • Nombre de lignes: 1,908,072
#    • Nombre de colonnes: 8
#    • Mémoire utilisée: 580.87 MB
#
# 2️⃣  TYPES DE DONNÉES:
#    • ('mid',)                  : object
#    • ('ordering',)             : int64
#    • ('title',)                : object
#    • ('region',)               : object
#    • ('language',)             : object
#    • ('types',)                : object
#    • ('attributes',)           : object
#    • ('isOriginalTitle',)      : int64
#
# 3️⃣  VALEURS MANQUANTES (NaN):
#    • ('region',)               :  196,077 valeurs manquantes ( 10.28%)
#    • ('language',)             : 1,511,761 valeurs manquantes ( 79.23%)
#    • ('types',)                :  422,866 valeurs manquantes ( 22.16%)
#    • ('attributes',)           : 1,812,099 valeurs manquantes ( 94.97%)
#
# 4️⃣  CHAÎNES VIDES (pour colonnes texte):
#    ✓ Aucune chaîne vide détectée
#
# 5️⃣  VALEURS UNIQUES (CARDINALITÉ):
#    • ('mid',)                  :  253,577 uniques ( 13.29%)
#    • ('ordering',)             :      177 uniques (  0.01%)
#    • ('title',)                : 1,111,958 uniques ( 58.28%)
#    • ('region',)               :      185 uniques (  0.01%)
#    • ('language',)             :       84 uniques (  0.00%)
#    • ('types',)                :       23 uniques (  0.00%)
#    • ('attributes',)           :      168 uniques (  0.01%)
#    • ('isOriginalTitle',)      :        2 uniques (  0.00%)
#
# 6️⃣  PREMIÈRES LIGNES:
#     ('mid',)  ('ordering',)                 ('title',) ('region',) ('language',)   ('types',) ('attributes',)  ('isOriginalTitle',)
# 0  tt0000001              1                 Карменсіта          UA           NaN  imdbDisplay             NaN                     0
# 1  tt0000001              2                 Carmencita          DE           NaN          NaN   literal title                     0
# 2  tt0000001              3  Carmencita - spanyol tánc          HU           NaN  imdbDisplay             NaN                     0
#
# 7️⃣  STATISTIQUES NUMÉRIQUES:
#        ('ordering',)  ('isOriginalTitle',)
# count   1.908072e+06          1.908072e+06
# mean    9.838294e+00          9.131783e-02
# std     9.850208e+00          2.880606e-01
# min     1.000000e+00          0.000000e+00
# 25%     3.000000e+00          0.000000e+00
# 50%     6.000000e+00          0.000000e+00
# 75%     1.400000e+01          0.000000e+00
# max     1.770000e+02          1.000000e+00
#
#
# ================================================================================
# 📋 TABLE: WRITERS
# ================================================================================
#
# 1️⃣  DIMENSIONS:
#    • Nombre de lignes: 900,485
#    • Nombre de colonnes: 2
#    • Mémoire utilisée: 99.71 MB
#
# 2️⃣  TYPES DE DONNÉES:
#    • ('mid',)                  : object
#    • ('pid',)                  : object
#
# 3️⃣  VALEURS MANQUANTES (NaN):
#    ✓ Aucune valeur manquante détectée
#
# 4️⃣  CHAÎNES VIDES (pour colonnes texte):
#    ✓ Aucune chaîne vide détectée
#
# 5️⃣  VALEURS UNIQUES (CARDINALITÉ):
#    • ('mid',)                  :  269,127 uniques ( 29.89%)
#    • ('pid',)                  :  172,611 uniques ( 19.17%)
#
# 6️⃣  PREMIÈRES LIGNES:
#     ('mid',)   ('pid',)
# 0  tt0000009  nm0085156
# 1  tt0000036  nm0410331
# 2  tt0000076  nm0410331
#
# 7️⃣  STATISTIQUES NUMÉRIQUES:
#    (Aucune colonne numérique)
#
#
# ================================================================================
# 📊 RÉSUMÉ GLOBAL DE L'EXPLORATION
# ================================================================================
#
# ✓ Total des lignes: 11,919,668
# ✓ Total des colonnes: 45
# ✓ Mémoire totale: 2102.88 MB
#
# ✅ Exploration des données terminée!

# %%
import pandas as pd
from pathlib import Path
import numpy as np
import matplotlib
matplotlib.use('Agg')  # ← SOLUTION : Utiliser le backend Agg (pas d'affichage interactif)
import matplotlib.pyplot as plt
import re

# ============================================================================
# 1. CHARGER LES CSV
# ============================================================================

CSV_PATH = Path('./csv')

print("\n" + "="*80)
print("📚 CHARGEMENT DES FICHIERS CSV")
print("="*80)

if not CSV_PATH.exists():
    print(f"\n❌ ERREUR: Le dossier '{CSV_PATH}' n'existe pas!")
    exit(1)

print(f"✓ Dossier trouvé: {CSV_PATH.absolute()}")

# ============================================================================
# 2. FONCTION POUR NETTOYER LES NOMS DE COLONNES
# ============================================================================

def clean_column_names(df):
    """
    Nettoie les noms de colonnes en supprimant les caractères inutiles.
    Transforme "('mid',)" en "mid"
    """
    new_columns = []
    for col in df.columns:
        # Supprimer les guillemets, parenthèses et caractères spéciaux
        cleaned = re.sub(r"[\"'(),]", "", col)
        cleaned = cleaned.strip()
        new_columns.append(cleaned)

    df.columns = new_columns
    return df

# ============================================================================
# 3. CHARGER ET NETTOYER LES CSV
# ============================================================================

dfs = {}

for filepath in sorted(CSV_PATH.glob('*.csv')):
    filename = filepath.name
    table_name = filename.replace('.csv', '').lower()  # MINUSCULES !
    try:
        df = pd.read_csv(filepath)
        # Nettoyer les noms des colonnes
        df = clean_column_names(df)
        dfs[table_name] = df
        print(f"✓ {table_name.upper():20} ({len(df):>8,} lignes, {len(df.columns)} colonnes)")
    except Exception as e:
        print(f"❌ Erreur: {filename}: {e}")

print(f"\n✓ Total chargé: {len(dfs)} fichiers")

# ============================================================================
# 4. AFFICHER LES NOMS DE COLONNES NETTOYÉS (pour vérification)
# ============================================================================

print("\n" + "="*80)
print("📝 NOMS DES COLONNES (NETTOYÉS)")
print("="*80)

for table_name, df in sorted(dfs.items()):
    print(f"\n{table_name.upper()}:")
    print(f"  {df.columns.tolist()}")

# ============================================================================
# 5. ANALYSES EXPLORATOIRES
# ============================================================================

print("\n\n" + "="*80)
print("📊 ANALYSES EXPLORATOIRES")
print("="*80)

# ========================
# 5.1 DISTRIBUTION DES FILMS PAR ANNÉE
# ========================

print("\n\n" + "="*80)
print("📅 1️⃣  DISTRIBUTION DES FILMS PAR ANNÉE")
print("="*80)

if 'movies' in dfs:  # minuscules !
    df_movies = dfs['movies']

    print(f"\n✓ Table 'movies' trouvée")

    if 'startYear' in df_movies.columns:
        print(f"✓ Colonne 'startYear' trouvée")

        # Nettoyer les données (supprimer les NaN)
        df_year = df_movies[['startYear']].copy()
        df_year['startYear'] = pd.to_numeric(df_year['startYear'], errors='coerce')
        df_year = df_year.dropna()

        print(f"\nStatistiques de base:")
        print(f"   • Année minimale: {df_year['startYear'].min():.0f}")
        print(f"   • Année maximale: {df_year['startYear'].max():.0f}")
        print(f"   • Année médiane: {df_year['startYear'].median():.0f}")
        print(f"   • Année moyenne: {df_year['startYear'].mean():.0f}")

        # Films par décennie
        df_year['decade'] = (df_year['startYear'] // 10 * 10).astype(int)
        decade_counts = df_year['decade'].value_counts().sort_index()

        print(f"\nFilms par décennie:")
        for decade, count in decade_counts.items():
            pct = (count / len(df_year) * 100)
            print(f"   {int(decade)}s: {count:>8,} films ({pct:>6.2f}%)")

        # Créer l'histogramme
        fig, ax = plt.subplots(figsize=(14, 6))
        decade_counts.plot(kind='bar', ax=ax, color='steelblue', edgecolor='black')
        ax.set_title('Distribution des films par décennie', fontsize=14, fontweight='bold')
        ax.set_xlabel('Décennie')
        ax.set_ylabel('Nombre de films')
        ax.grid(axis='y', alpha=0.3)
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.savefig('analyse_films_par_annee.png', dpi=100, bbox_inches='tight')
        print(f"\n✓ Graphique sauvegardé: analyse_films_par_annee.png")
        plt.close()
    else:
        print(f"⚠️  Colonne 'startYear' non trouvée")
else:
    print(f"⚠️  Table 'movies' non trouvée")

# ========================
# 5.2 TOP 10 DES GENRES LES PLUS FRÉQUENTS
# ========================

print("\n\n" + "="*80)
print("🎭 2️⃣  TOP 10 DES GENRES LES PLUS FRÉQUENTS")
print("="*80)

if 'genres' in dfs:  # minuscules !
    df_genres = dfs['genres']

    print(f"\n✓ Table 'genres' trouvée")

    if 'genre' in df_genres.columns:
        print(f"✓ Colonne 'genre' trouvée")

        genre_counts = df_genres['genre'].value_counts().head(10)

        print(f"\nTop 10 des genres:")
        for i, (genre, count) in enumerate(genre_counts.items(), 1):
            pct = (count / len(df_genres) * 100)
            print(f"   {i:2}. {genre:25} : {count:>8,} ({pct:>6.2f}%)")

        # Créer le graphique (barres horizontales)
        fig, ax = plt.subplots(figsize=(12, 6))
        genre_counts.plot(kind='barh', ax=ax, color='coral', edgecolor='black')
        ax.set_title('Top 10 des genres les plus fréquents', fontsize=14, fontweight='bold')
        ax.set_xlabel('Nombre d\'associations film-genre')
        ax.invert_yaxis()
        ax.grid(axis='x', alpha=0.3)
        plt.tight_layout()
        plt.savefig('top10_genres.png', dpi=100, bbox_inches='tight')
        print(f"\n✓ Graphique sauvegardé: top10_genres.png")
        plt.close()
    else:
        print(f"⚠️  Colonne 'genre' non trouvée")
else:
    print(f"⚠️  Table 'genres' non trouvée")

# ========================
# 5.3 DISTRIBUTION DES NOTES (RATINGS)
# ========================

print("\n\n" + "="*80)
print("⭐ 3️⃣  DISTRIBUTION DES NOTES (RATINGS)")
print("="*80)

if 'ratings' in dfs:  # minuscules !
    df_ratings = dfs['ratings']

    print(f"\n✓ Table 'ratings' trouvée")

    if 'averageRating' in df_ratings.columns:
        print(f"✓ Colonne 'averageRating' trouvée")

        # Nettoyer les données
        df_rating = df_ratings[['averageRating']].copy()
        df_rating['averageRating'] = pd.to_numeric(df_rating['averageRating'], errors='coerce')
        df_rating = df_rating.dropna()

        rating_stats = df_rating['averageRating'].describe()

        print(f"\nStatistiques des notes:")
        print(f"   • Note minimale: {rating_stats['min']:.1f}")
        print(f"   • Note maximale: {rating_stats['max']:.1f}")
        print(f"   • Note moyenne: {rating_stats['mean']:.2f}")
        print(f"   • Note médiane: {rating_stats['50%']:.1f}")
        print(f"   • Écart-type: {rating_stats['std']:.2f}")

        # Distribution par plages
        print(f"\nDistribution par plages:")
        bins = [0, 2, 4, 6, 8, 10]
        hist, _ = np.histogram(df_rating['averageRating'], bins=bins)
        for i in range(len(bins)-1):
            pct = (hist[i] / len(df_rating) * 100)
            print(f"   {bins[i]:.1f} - {bins[i+1]:.1f}: {hist[i]:>8,} ({pct:>6.2f}%)")

        # Créer les graphiques
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

        # Histogramme
        ax1.hist(df_rating['averageRating'], bins=50, color='skyblue', edgecolor='black')
        ax1.set_title('Distribution des notes (histogramme)', fontsize=12, fontweight='bold')
        ax1.set_xlabel('Note moyenne')
        ax1.set_ylabel('Fréquence')
        ax1.axvline(df_rating['averageRating'].mean(), color='red', linestyle='--',
                    label=f'Moyenne: {df_rating["averageRating"].mean():.2f}')
        ax1.legend()
        ax1.grid(axis='y', alpha=0.3)

        # Box plot
        ax2.boxplot(df_rating['averageRating'], vert=True)
        ax2.set_title('Box plot des notes', fontsize=12, fontweight='bold')
        ax2.set_ylabel('Note moyenne')
        ax2.grid(axis='y', alpha=0.3)

        plt.tight_layout()
        plt.savefig('distribution_notes.png', dpi=100, bbox_inches='tight')
        print(f"\n✓ Graphique sauvegardé: distribution_notes.png")
        plt.close()
    else:
        print(f"⚠️  Colonne 'averageRating' non trouvée")
else:
    print(f"⚠️  Table 'ratings' non trouvée")

# ========================
# 5.4 NOMBRE MOYEN D'ACTEURS PAR FILM
# ========================

print("\n\n" + "="*80)
print("🎬 4️⃣  NOMBRE MOYEN D'ACTEURS PAR FILM")
print("="*80)

if 'principals' in dfs:  # minuscules !
    df_principals = dfs['principals']

    print(f"\n✓ Table 'principals' trouvée")

    if 'mid' in df_principals.columns:
        print(f"✓ Colonne 'mid' (movie_id) trouvée")

        # Compter les acteurs par film
        actors_per_film = df_principals.groupby('mid').size()

        print(f"\nStatistiques:")
        print(f"   • Nombre moyen d'acteurs/personnages: {actors_per_film.mean():.2f}")
        print(f"   • Médiane: {actors_per_film.median():.0f}")
        print(f"   • Minimum: {actors_per_film.min()}")
        print(f"   • Maximum: {actors_per_film.max()}")
        print(f"   • Écart-type: {actors_per_film.std():.2f}")

        # Distribution par plages
        print(f"\nDistribution par nombre d'acteurs:")
        bins_actors = [0, 5, 10, 15, 20, 50, 100, 1000]
        hist, _ = np.histogram(actors_per_film, bins=bins_actors)
        for i in range(len(bins_actors)-1):
            pct = (hist[i] / len(actors_per_film) * 100)
            print(f"   {bins_actors[i]:>3} - {bins_actors[i+1]:>3}: {hist[i]:>8,} films ({pct:>6.2f}%)")

        # Créer le graphique
        fig, ax = plt.subplots(figsize=(12, 6))
        ax.hist(actors_per_film, bins=50, color='lightgreen', edgecolor='black')
        ax.set_title('Distribution du nombre d\'acteurs/personnages par film',
                     fontsize=12, fontweight='bold')
        ax.set_xlabel('Nombre de principaux par film')
        ax.set_ylabel('Nombre de films')
        ax.axvline(actors_per_film.mean(), color='red', linestyle='--',
                   label=f'Moyenne: {actors_per_film.mean():.2f}')
        ax.axvline(actors_per_film.median(), color='orange', linestyle='--',
                   label=f'Médiane: {actors_per_film.median():.0f}')
        ax.legend()
        ax.grid(axis='y', alpha=0.3)
        plt.tight_layout()
        plt.savefig('acteurs_par_film.png', dpi=100, bbox_inches='tight')
        print(f"\n✓ Graphique sauvegardé: acteurs_par_film.png")
        plt.close()
    else:
        print(f"⚠️  Colonne 'mid' non trouvée")
else:
    print(f"⚠️  Table 'principals' non trouvée")

# ============================================================================
# 6. RÉSUMÉ FINAL
# ============================================================================

print("\n\n" + "="*80)
print("✅ ANALYSES EXPLORATOIRES TERMINÉES")
print("="*80)

print(f"\n📊 Graphiques générés:")
print(f"   1. analyse_films_par_annee.png")
print(f"   2. top10_genres.png")
print(f"   3. distribution_notes.png")
print(f"   4. acteurs_par_film.png")

print(f"\n💡 Les graphiques sont sauvegardés dans le répertoire courant")
print(f"   Vous pouvez les ouvrir avec un lecteur d'images")

print(f"\n{'='*80}\n")
# Out:
# ================================================================================
# 📚 CHARGEMENT DES FICHIERS CSV
# ================================================================================
# ✓ Dossier trouvé: /home/omar/Bureau/4A/Bases_de_Données_Avancées/cineexplorer/data/csv
# ✓ CHARACTERS           (1,405,274 lignes, 3 colonnes)
# ✓ DIRECTORS            ( 419,861 lignes, 2 colonnes)
# ✓ EPISODES             ( 115,576 lignes, 4 colonnes)
# ✓ GENRES               ( 649,379 lignes, 2 colonnes)
# ✓ KNOWNFORMOVIES       (1,328,773 lignes, 2 colonnes)
# ✓ MOVIES               ( 291,238 lignes, 8 colonnes)
# ✓ PERSONS              ( 632,324 lignes, 4 colonnes)
# ✓ PRINCIPALS           (2,745,688 lignes, 5 colonnes)
# ✓ PROFESSIONS          (1,231,760 lignes, 2 colonnes)
# ✓ RATINGS              ( 291,238 lignes, 3 colonnes)
# ✓ TITLES               (1,908,072 lignes, 8 colonnes)
# ✓ WRITERS              ( 900,485 lignes, 2 colonnes)
#
# ✓ Total chargé: 12 fichiers
#
# ================================================================================
# 📝 NOMS DES COLONNES (NETTOYÉS)
# ================================================================================
#
# CHARACTERS:
#   ['mid', 'pid', 'name']
#
# DIRECTORS:
#   ['mid', 'pid']
#
# EPISODES:
#   ['mid', 'parentMid', 'seasonNumber', 'episodeNumber']
#
# GENRES:
#   ['mid', 'genre']
#
# KNOWNFORMOVIES:
#   ['pid', 'mid']
#
# MOVIES:
#   ['mid', 'titleType', 'primaryTitle', 'originalTitle', 'isAdult', 'startYear', 'endYear', 'runtimeMinutes']
#
# PERSONS:
#   ['pid', 'primaryName', 'birthYear', 'deathYear']
#
# PRINCIPALS:
#   ['mid', 'ordering', 'pid', 'category', 'job']
#
# PROFESSIONS:
#   ['pid', 'jobName']
#
# RATINGS:
#   ['mid', 'averageRating', 'numVotes']
#
# TITLES:
#   ['mid', 'ordering', 'title', 'region', 'language', 'types', 'attributes', 'isOriginalTitle']
#
# WRITERS:
#   ['mid', 'pid']
#
#
# ================================================================================
# 📊 ANALYSES EXPLORATOIRES
# ================================================================================
#
#
# ================================================================================
# 📅 1️⃣  DISTRIBUTION DES FILMS PAR ANNÉE
# ================================================================================
#
# ✓ Table 'movies' trouvée
# ✓ Colonne 'startYear' trouvée
#
# Statistiques de base:
#    • Année minimale: 1874
#    • Année maximale: 2022
#    • Année médiane: 2008
#    • Année moyenne: 2001
#
# Films par décennie:
#    1870s:        3 films (  0.00%)
#    1880s:       29 films (  0.01%)
#    1890s:      556 films (  0.19%)
#    1900s:      622 films (  0.21%)
#    1910s:      675 films (  0.23%)
#    1920s:    1,222 films (  0.42%)
#    1930s:    4,471 films (  1.54%)
#    1940s:    4,654 films (  1.60%)
#    1950s:    7,024 films (  2.41%)
#    1960s:   11,456 films (  3.93%)
#    1970s:   13,577 films (  4.66%)
#    1980s:   17,469 films (  6.00%)
#    1990s:   31,523 films ( 10.82%)
#    2000s:   61,179 films ( 21.01%)
#    2010s:  112,818 films ( 38.74%)
#    2020s:   23,960 films (  8.23%)
#
# ✓ Graphique sauvegardé: analyse_films_par_annee.png
#
#
# ================================================================================
# 🎭 2️⃣  TOP 10 DES GENRES LES PLUS FRÉQUENTS
# ================================================================================
#
# ✓ Table 'genres' trouvée
# ✓ Colonne 'genre' trouvée
#
# Top 10 des genres:
#     1. Drama                     :  138,499 ( 21.33%)
#     2. Comedy                    :  100,811 ( 15.52%)
#     3. Action                    :   55,128 (  8.49%)
#     4. Crime                     :   46,429 (  7.15%)
#     5. Adventure                 :   42,797 (  6.59%)
#     6. Animation                 :   34,917 (  5.38%)
#     7. Romance                   :   32,335 (  4.98%)
#     8. Mystery                   :   25,319 (  3.90%)
#     9. Thriller                  :   22,224 (  3.42%)
#    10. Family                    :   20,703 (  3.19%)
#
# ✓ Graphique sauvegardé: top10_genres.png
#
#
# ================================================================================
# ⭐ 3️⃣  DISTRIBUTION DES NOTES (RATINGS)
# ================================================================================
#
# ✓ Table 'ratings' trouvée
# ✓ Colonne 'averageRating' trouvée
#
# Statistiques des notes:
#    • Note minimale: 1.0
#    • Note maximale: 10.0
#    • Note moyenne: 6.83
#    • Note médiane: 7.1
#    • Écart-type: 1.40
#
# Distribution par plages:
#    0.0 - 2.0:    1,091 (  0.37%)
#    2.0 - 4.0:   11,359 (  3.90%)
#    4.0 - 6.0:   54,486 ( 18.71%)
#    6.0 - 8.0:  163,268 ( 56.06%)
#    8.0 - 10.0:   61,034 ( 20.96%)
#
# ✓ Graphique sauvegardé: distribution_notes.png
#
#
# ================================================================================
# 🎬 4️⃣  NOMBRE MOYEN D'ACTEURS PAR FILM
# ================================================================================
#
# ✓ Table 'principals' trouvée
# ✓ Colonne 'mid' (movie_id) trouvée
#
# Statistiques:
#    • Nombre moyen d'acteurs/personnages: 9.45
#    • Médiane: 10
#    • Minimum: 1
#    • Maximum: 10
#    • Écart-type: 1.60
#
# Distribution par nombre d'acteurs:
#      0 -   5:   10,322 films (  3.55%)
#      5 -  10:   38,701 films ( 13.31%)
#     10 -  15:  241,645 films ( 83.13%)
#     15 -  20:        0 films (  0.00%)
#     20 -  50:        0 films (  0.00%)
#     50 - 100:        0 films (  0.00%)
#    100 - 1000:        0 films (  0.00%)
#
# ✓ Graphique sauvegardé: acteurs_par_film.png
#
#
# ================================================================================
# ✅ ANALYSES EXPLORATOIRES TERMINÉES
# ================================================================================
#
# 📊 Graphiques générés:
#    1. analyse_films_par_annee.png
#    2. top10_genres.png
#    3. distribution_notes.png
#    4. acteurs_par_film.png
#
# 💡 Les graphiques sont sauvegardés dans le répertoire courant
#    Vous pouvez les ouvrir avec un lecteur d'images
#
# ================================================================================
